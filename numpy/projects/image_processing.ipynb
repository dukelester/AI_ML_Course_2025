# %% [markdown]
# # Image Processing with NumPy
#
# ### Problem: Work with an image as a NumPy array.
#
# Questions to solve:
#
#     - Convert a color image to grayscale using matrix operations.
#
#     - Apply a blur filter (average kernel).
#
#     - Detect edges using a Sobel filter (convolution).

# %%
print('Image processing')
# Out:
# Image processing

# %%
import numpy as np
import matplotlib.pyplot as plt

from PIL import Image, ImageOps

# %%
# Open the image

image = np.array(Image.open("userimage.png"))
plt.figure(figsize=(10, 10))
plt.imshow(image)

# %%
image
# Out:
# array([[[220, 216, 215, 255],
#         [220, 216, 215, 255],
#         [220, 216, 215, 255],
#         ...,
#         [235, 233, 234, 255],
#         [235, 233, 234, 255],
#         [235, 233, 234, 255]],
#
#        [[220, 216, 215, 255],
#         [220, 216, 215, 255],
#         [220, 216, 215, 255],
#         ...,
#         [235, 233, 234, 255],
#         [235, 233, 234, 255],
#         [235, 233, 234, 255]],
#
#        [[220, 216, 215, 255],
#         [220, 216, 215, 255],
#         [220, 216, 215, 255],
#         ...,
#         [235, 233, 234, 255],
#         [235, 233, 234, 255],
#         [235, 233, 234, 255]],
#
#        ...,
#
#        [[217, 186, 159, 255],
#         [217, 186, 161, 255],
#         [219, 189, 163, 255],
#         ...,
#         [177, 163, 152, 255],
#         [193, 180, 179, 255],
#         [202, 188, 188, 255]],
#
#        [[217, 186, 159, 255],
#         [218, 187, 162, 255],
#         [219, 189, 163, 255],
#         ...,
#         [189, 175, 164, 255],
# ...

# %%
img = Image.open('userimage.png')
img.show()

# %%
print({
    "Image Dimension": image.ndim,
    "Image Shape": image.shape,
    "Image Size": image.size,
    "Image data type": image.dtype
})
# Out:
# {'Image Dimension': 3, 'Image Shape': (387, 506, 4), 'Image Size': 783288, 'Image data type': dtype('uint8')}

# %%
# The pixel value 
print(image[20, 20])
# Out:
# [218 214 213 255]

# %%
# save the ndarray as image

path = 'newuser.png'
pil_image = Image.fromarray(image)
pil_image.save(path)

# %%
new_sample_img = np.linspace(233, 3000)
new_sample_img
# Out:
# array([ 233.        ,  289.46938776,  345.93877551,  402.40816327,
#         458.87755102,  515.34693878,  571.81632653,  628.28571429,
#         684.75510204,  741.2244898 ,  797.69387755,  854.16326531,
#         910.63265306,  967.10204082, 1023.57142857, 1080.04081633,
#        1136.51020408, 1192.97959184, 1249.44897959, 1305.91836735,
#        1362.3877551 , 1418.85714286, 1475.32653061, 1531.79591837,
#        1588.26530612, 1644.73469388, 1701.20408163, 1757.67346939,
#        1814.14285714, 1870.6122449 , 1927.08163265, 1983.55102041,
#        2040.02040816, 2096.48979592, 2152.95918367, 2209.42857143,
#        2265.89795918, 2322.36734694, 2378.83673469, 2435.30612245,
#        2491.7755102 , 2548.24489796, 2604.71428571, 2661.18367347,
#        2717.65306122, 2774.12244898, 2830.59183673, 2887.06122449,
#        2943.53061224, 3000.        ])
