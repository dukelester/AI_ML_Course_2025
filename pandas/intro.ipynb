# %%
import pandas as pd

# %%
series = pd.Series(['Duke', 'Lester', 'Ki', 'Jess'])
series
# Out:
# 0      Duke
# 1    Lester
# 2        Ki
# 3      Jess
# dtype: object

# %%
list(series)
# Out:
# ['Duke', 'Lester', 'Ki', 'Jess']

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
car_data = pd.read_csv('car-sales.csv')
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_data.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
result = car_data.head(3), car_data.tail(3)
print(result)
# Out:
# (     Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00,      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00)

# %%
type(result)
# Out:
# tuple

# %%
car_data['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_data['Doors']
# Out:
# 0    4
# 1    4
# 2    3
# 3    5
# 4    4
# 5    4
# 6    4
# 7    4
# 8    4
# 9    4
# Name: Doors, dtype: int64

# %%
series = car_data['Make']
series
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
car_data['Make'] == 'Honda'
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8    False
# 9    False
# Name: Make, dtype: bool

# %%
list(car_data['Make'])
# Out:
# ['Toyota',
#  'Honda',
#  'Toyota',
#  'BMW',
#  'Nissan',
#  'Toyota',
#  'Honda',
#  'Honda',
#  'Toyota',
#  'Nissan']

# %%
honda = len([make for make in list(car_data['Make']) if make == 'Honda'])
honda
# Out:
# 3

# %%
nissan = len([make for make in list(car_data['Make']) if make == 'Nissan'])
nissan
# Out:
# 2

# %%
car_data.shape
# Out:
# (10, 5)

# %%
car_data.size
# Out:
# 50

# %%
car_data.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data['Price']
# Out:
# 0     $4,000.00
# 1     $5,000.00
# 2     $7,000.00
# 3    $22,000.00
# 4     $3,500.00
# 5     $4,500.00
# 6     $7,500.00
# 7     $7,000.00
# 8     $6,250.00
# 9     $9,700.00
# Name: Price, dtype: object

# %%
'duke'.replace('d', '')
# Out:
# 'uke'

# %%
int(car_data['Price'][0].replace('$', '').replace(',', '')[:-3])
# Out:
# 4000

# %%
def transform(price):
    return int(price.replace('$', '').replace(',', '')[:-3]) * 127

# %%
transform(car_data['Price'][0])
# Out:
# 508000

# %%
transformed = [transform(price) for price in car_data['Price']]
transformed
# Out:
# [508000,
#  635000,
#  889000,
#  2794000,
#  444500,
#  571500,
#  952500,
#  889000,
#  793750,
#  1231900]

# %%
car_data['price in KES'] = transformed

# %%
car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  price in KES
# 0  Toyota  White         150043      4   $4,000.00        508000
# 1   Honda    Red          87899      4   $5,000.00        635000
# 2  Toyota   Blue          32549      3   $7,000.00        889000
# 3     BMW  Black          11179      5  $22,000.00       2794000
# 4  Nissan  White         213095      4   $3,500.00        444500
# 5  Toyota  Green          99213      4   $4,500.00        571500
# 6   Honda   Blue          45698      4   $7,500.00        952500
# 7   Honda   Blue          54738      4   $7,000.00        889000
# 8  Toyota  White          60000      4   $6,250.00        793750
# 9  Nissan  White          31600      4   $9,700.00       1231900

# %%
car_data.to_csv('new_cars.csv', index=False)

# %%
new_car_data = pd.read_csv('new_cars.csv')
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  price in KES
# 0  Toyota  White         150043      4   $4,000.00        508000
# 1   Honda    Red          87899      4   $5,000.00        635000
# 2  Toyota   Blue          32549      3   $7,000.00        889000
# 3     BMW  Black          11179      5  $22,000.00       2794000
# 4  Nissan  White         213095      4   $3,500.00        444500
# 5  Toyota  Green          99213      4   $4,500.00        571500
# 6   Honda   Blue          45698      4   $7,500.00        952500
# 7   Honda   Blue          54738      4   $7,000.00        889000
# 8  Toyota  White          60000      4   $6,250.00        793750
# 9  Nissan  White          31600      4   $9,700.00       1231900

# %%
max(new_car_data['price in KES'])
# Out:
# 2794000

# %%
new_car_data.describe()
# Out:
#        Odometer (KM)      Doors  price in KES
# count      10.000000  10.000000  1.000000e+01
# mean    78601.400000   4.000000  9.709150e+05
# std     61983.471735   0.471405  6.831848e+05
# min     11179.000000   3.000000  4.445000e+05
# 25%     35836.250000   4.000000  5.873750e+05
# 50%     57369.000000   4.000000  8.413750e+05
# 75%     96384.500000   4.000000  9.366250e+05
# max    213095.000000   5.000000  2.794000e+06

# %%
new_car_data.mean()
# Out:
# /tmp/ipykernel_85319/3507405841.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   new_car_data.mean()
# Odometer (KM)     78601.4
# Doors                 4.0
# price in KES     970915.0
# dtype: float64

# %%
new_car_data.min(numeric_only=True)
# Out:
# Odometer (KM)     11179
# Doors                 3
# price in KES     444500
# dtype: int64

# %%
new_car_data.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# price in KES      int64
# dtype: object

# %%
columns = new_car_data.columns
columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price', 'price in KES'], dtype='object')

# %%
new_car_data.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
new_car_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
#  5   price in KES   10 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 608.0+ bytes

# %%
new_car_data.mean(numeric_only=True)
# Out:
# Odometer (KM)     78601.4
# Doors                 4.0
# price in KES     970915.0
# dtype: float64

# %%
new_car_data.sum(numeric_only=True)
# Out:
# Odometer (KM)     786014
# Doors                 40
# price in KES     9709150
# dtype: int64

# %%
new_car_data.loc[2] # Index
# Out:
# Make                Toyota
# Colour                Blue
# Odometer (KM)        32549
# Doors                    3
# Price            $7,000.00
# price in KES        889000
# Name: 2, dtype: object

# %%
new_car_data.iloc[3]  # Position
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# price in KES        2794000
# Name: 3, dtype: object

# %%
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  price in KES
# 0  Toyota  White         150043      4   $4,000.00        508000
# 1   Honda    Red          87899      4   $5,000.00        635000
# 2  Toyota   Blue          32549      3   $7,000.00        889000
# 3     BMW  Black          11179      5  $22,000.00       2794000
# 4  Nissan  White         213095      4   $3,500.00        444500
# 5  Toyota  Green          99213      4   $4,500.00        571500
# 6   Honda   Blue          45698      4   $7,500.00        952500
# 7   Honda   Blue          54738      4   $7,000.00        889000
# 8  Toyota  White          60000      4   $6,250.00        793750
# 9  Nissan  White          31600      4   $9,700.00       1231900

# %%
new_car_data.loc[3:8]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  price in KES
# 3     BMW  Black          11179      5  $22,000.00       2794000
# 4  Nissan  White         213095      4   $3,500.00        444500
# 5  Toyota  Green          99213      4   $4,500.00        571500
# 6   Honda   Blue          45698      4   $7,500.00        952500
# 7   Honda   Blue          54738      4   $7,000.00        889000
# 8  Toyota  White          60000      4   $6,250.00        793750

# %%
new_car_data.iloc[3:8]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  price in KES
# 3     BMW  Black          11179      5  $22,000.00       2794000
# 4  Nissan  White         213095      4   $3,500.00        444500
# 5  Toyota  Green          99213      4   $4,500.00        571500
# 6   Honda   Blue          45698      4   $7,500.00        952500
# 7   Honda   Blue          54738      4   $7,000.00        889000

# %%
new_car_data.iloc[0].Make
# Out:
# 'Toyota'

# %%
new_car_data[new_car_data["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  price in KES
# 0  Toyota  White         150043      4  $4,000.00        508000
# 2  Toyota   Blue          32549      3  $7,000.00        889000
# 5  Toyota  Green          99213      4  $4,500.00        571500
# 8  Toyota  White          60000      4  $6,250.00        793750

# %%
len(new_car_data[new_car_data["Make"] == "Toyota"])
# Out:
# 4

# %%
expensive = new_car_data[new_car_data['price in KES'] > 571500]

expensive[expensive['Colour'] == 'Blue']
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  price in KES
# 2  Toyota   Blue          32549      3  $7,000.00        889000
# 6   Honda   Blue          45698      4  $7,500.00        952500
# 7   Honda   Blue          54738      4  $7,000.00        889000

# %%
print(new_car_data)
new_car_data['Price'] = new_car_data['Price'].str.replace('[\$\, \.]', '', regex=True)
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors       Price  price in KES
# 0  Toyota  White         150043      4   $4,000.00        508000
# 1   Honda    Red          87899      4   $5,000.00        635000
# 2  Toyota   Blue          32549      3   $7,000.00        889000
# 3     BMW  Black          11179      5  $22,000.00       2794000
# 4  Nissan  White         213095      4   $3,500.00        444500
# 5  Toyota  Green          99213      4   $4,500.00        571500
# 6   Honda   Blue          45698      4   $7,500.00        952500
# 7   Honda   Blue          54738      4   $7,000.00        889000
# 8  Toyota  White          60000      4   $6,250.00        793750
# 9  Nissan  White          31600      4   $9,700.00       1231900
#      Make Colour  Odometer (KM)  Doors    Price  price in KES
# 0  Toyota  White         150043      4   400000        508000
# 1   Honda    Red          87899      4   500000        635000
# 2  Toyota   Blue          32549      3   700000        889000
# ...

# %%
hondas = new_car_data.groupby(['Make']).mean()
hondas
# Out:
#         Odometer (KM)  Doors  price in KES
# Make
# BMW      11179.000000   5.00     2794000.0
# Honda    62778.333333   4.00      825500.0
# Nissan  122347.500000   4.00      838200.0
# Toyota   85451.250000   3.75      690562.5

# %%
new_car_data.groupby(['Colour']).describe()
# Out:
#        Odometer (KM)                                                           \
#                count           mean           std      min      25%       50%
# Colour
# Black            1.0   11179.000000           NaN  11179.0  11179.0   11179.0
# Blue             3.0   44328.333333  11157.729175  32549.0  39123.5   45698.0
# Green            1.0   99213.000000           NaN  99213.0  99213.0   99213.0
# Red              1.0   87899.000000           NaN  87899.0  87899.0   87899.0
# White            4.0  113684.500000  83315.222125  31600.0  52900.0  105021.5
#
#                            Doors            ...           price in KES  \
#              75%       max count      mean  ...  75%  max        count
# Colour                                      ...
# Black    11179.0   11179.0   1.0  5.000000  ...  5.0  5.0          1.0
# Blue     50218.0   54738.0   3.0  3.666667  ...  4.0  4.0          3.0
# Green    99213.0   99213.0   1.0  4.000000  ...  4.0  4.0          1.0
# ...

# %%
new_car_data['Odometer (KM)'].plot()
# Out:
# <AxesSubplot:>

# %%
new_car_data['Price'].hist()
# Out:
# <AxesSubplot:>

# %%
new_car_data['Doors'].plot()
# Out:
# <AxesSubplot:>

# %%
int(40000.000)
# Out:
# 40000

# %%
new_car_data['Colour'].str.lower()
# Out:
# 0    white
# 1      red
# 2     blue
# 3    black
# 4    white
# 5    green
# 6     blue
# 7     blue
# 8    white
# 9    white
# Name: Colour, dtype: object

# %%
new_car_data['Colour'].str.upper()
# Out:
# 0    WHITE
# 1      RED
# 2     BLUE
# 3    BLACK
# 4    WHITE
# 5    GREEN
# 6     BLUE
# 7     BLUE
# 8    WHITE
# 9    WHITE
# Name: Colour, dtype: object

# %%
new_car_data['Seats'] = pd.Series([3, 4, 4, 5, 8, 7])

# %%
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    NaN
# 7   Honda   Blue          54738      4   700000        889000    NaN
# 8  Toyota  White          60000      4   625000        793750    NaN
# 9  Nissan  White          31600      4   970000       1231900    NaN

# %%
new_car_data.dropna()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0

# %%
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    NaN
# 7   Honda   Blue          54738      4   700000        889000    NaN
# 8  Toyota  White          60000      4   625000        793750    NaN
# 9  Nissan  White          31600      4   970000       1231900    NaN

# %%
new_dropped_missing = new_car_data.dropna()
new_dropped_missing
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0

# %%
new_car_data.fillna(4)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    4.0
# 7   Honda   Blue          54738      4   700000        889000    4.0
# 8  Toyota  White          60000      4   625000        793750    4.0
# 9  Nissan  White          31600      4   970000       1231900    4.0

# %%
list(new_car_data['Seats'])
# Out:
# [3.0, 4.0, 4.0, 5.0, 8.0, 7.0, nan, nan, nan, nan]

# %%
int('nan')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_85319/1151041865.py in <module>
# ----> 1 int('nan')
#
# ValueError: invalid literal for int() with base 10: 'nan'

# %%
new_car_data['Number of Wheels'] = 4

# %%
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    NaN
# 7   Honda   Blue          54738      4   700000        889000    NaN
# 8  Toyota  White          60000      4   625000        793750    NaN
# 9  Nissan  White          31600      4   970000       1231900    NaN
#
#    Number of Wheels
# 0                 4
# 1                 4
# 2                 4
# 3                 4
# 4                 4
# 5                 4
# 6                 4
# 7                 4
# ...

# %%
new_car_data['Fuel per 100 KM']  = [2.3, 7.5, 33.5, 3, 9.8, 6.8, 3, 3.4, 2.2, 7]
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    NaN
# 7   Honda   Blue          54738      4   700000        889000    NaN
# 8  Toyota  White          60000      4   625000        793750    NaN
# 9  Nissan  White          31600      4   970000       1231900    NaN
#
#    Number of Wheels  Fuel per 100 KM
# 0                 4              2.3
# 1                 4              7.5
# 2                 4             33.5
# 3                 4              3.0
# ...

# %%
new_car_data.dropna()
new_car_data
new_car_data['Fuel Economy'] = new_car_data['Fuel per 100 KM'] / 100 * new_car_data['Odometer (KM)']

new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    NaN
# 7   Honda   Blue          54738      4   700000        889000    NaN
# 8  Toyota  White          60000      4   625000        793750    NaN
# 9  Nissan  White          31600      4   970000       1231900    NaN
#
#    Number of Wheels  Fuel per 100 KM  Fuel Economy
# 0                 4              2.3      3450.989
# 1                 4              7.5      6592.425
# 2                 4             33.5     10903.915
# ...

# %%
data = new_car_data.dropna()

# %%
data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
#
#    Number of Wheels  Fuel per 100 KM
# 0                 4              2.3
# 1                 4              7.5
# 2                 4             33.5
# 3                 4              3.0
# 4                 4              9.8
# 5                 4              6.8

# %%
data['Fuel Economy'] = data['Fuel per 100 KM'] / 100 * data['Odometer (KM)']
data
# Out:
# /tmp/ipykernel_85319/2938356481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Fuel Economy'] = data['Fuel per 100 KM'] / 100 * data['Odometer (KM)']
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
#
#    Number of Wheels  Fuel per 100 KM  Fuel Economy
# ...

# %%
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    NaN
# 7   Honda   Blue          54738      4   700000        889000    NaN
# 8  Toyota  White          60000      4   625000        793750    NaN
# 9  Nissan  White          31600      4   970000       1231900    NaN
#
#    Number of Wheels  Fuel per 100 KM  Fuel Economy
# 0                 4              2.3      3450.989
# 1                 4              7.5      6592.425
# 2                 4             33.5     10903.915
# ...

# %%
new_car_data.describe()
# Out:
#        Odometer (KM)      Doors  price in KES     Seats  Number of Wheels  \
# count      10.000000  10.000000  1.000000e+01  6.000000              10.0
# mean    78601.400000   4.000000  9.709150e+05  5.166667               4.0
# std     61983.471735   0.471405  6.831848e+05  1.940790               0.0
# min     11179.000000   3.000000  4.445000e+05  3.000000               4.0
# 25%     35836.250000   4.000000  5.873750e+05  4.000000               4.0
# 50%     57369.000000   4.000000  8.413750e+05  4.500000               4.0
# 75%     96384.500000   4.000000  9.366250e+05  6.500000               4.0
# max    213095.000000   5.000000  2.794000e+06  8.000000               4.0
#
#        Fuel per 100 KM  Fuel Economy
# count        10.000000     10.000000
# mean          7.850000   5567.652500
# std           9.388202   6306.926096
# min           2.200000    335.370000
# 25%           3.000000   1493.478000
# 50%           5.100000   2831.494500
# ...

# %%
new_car_data['Passed Road Safety'] = True
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White         150043      4   400000        508000    3.0
# 1   Honda    Red          87899      4   500000        635000    4.0
# 2  Toyota   Blue          32549      3   700000        889000    4.0
# 3     BMW  Black          11179      5  2200000       2794000    5.0
# 4  Nissan  White         213095      4   350000        444500    8.0
# 5  Toyota  Green          99213      4   450000        571500    7.0
# 6   Honda   Blue          45698      4   750000        952500    NaN
# 7   Honda   Blue          54738      4   700000        889000    NaN
# 8  Toyota  White          60000      4   625000        793750    NaN
# 9  Nissan  White          31600      4   970000       1231900    NaN
#
#    Number of Wheels  Fuel per 100 KM  Fuel Economy  Passed Road Safety
# 0                 4              2.3      3450.989                True
# ...

# %%
new_car_data.drop('Seats', axis=1)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  \
# 0  Toyota  White         150043      4   400000        508000
# 1   Honda    Red          87899      4   500000        635000
# 2  Toyota   Blue          32549      3   700000        889000
# 3     BMW  Black          11179      5  2200000       2794000
# 4  Nissan  White         213095      4   350000        444500
# 5  Toyota  Green          99213      4   450000        571500
# 6   Honda   Blue          45698      4   750000        952500
# 7   Honda   Blue          54738      4   700000        889000
# 8  Toyota  White          60000      4   625000        793750
# 9  Nissan  White          31600      4   970000       1231900
#
#    Number of Wheels  Fuel per 100 KM  Fuel Economy  Passed Road Safety
# 0                 4              2.3      3450.989                True
# 1                 4              7.5      6592.425                True
# ...

# %%
new_car_data['Odometer (KM)'] = new_car_data['Odometer (KM)'].apply(lambda s: s / 1.609)
new_car_data
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 0  Toyota  White   93252.330640      4   400000        508000    3.0
# 1   Honda    Red   54629.583592      4   500000        635000    4.0
# 2  Toyota   Blue   20229.334991      3   700000        889000    4.0
# 3     BMW  Black    6947.793661      5  2200000       2794000    5.0
# 4  Nissan  White  132439.403356      4   350000        444500    8.0
# 5  Toyota  Green   61661.280298      4   450000        571500    7.0
# 6   Honda   Blue   28401.491610      4   750000        952500    NaN
# 7   Honda   Blue   34019.888129      4   700000        889000    NaN
# 8  Toyota  White   37290.242387      4   625000        793750    NaN
# 9  Nissan  White   19639.527657      4   970000       1231900    NaN
#
#    Number of Wheels  Fuel per 100 KM  Fuel Economy  Passed Road Safety
# 0                 4              2.3      3450.989                True
# ...

# %%
new_car_data.sort_values(by='Price', ascending=False)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  price in KES  Seats  \
# 9  Nissan  White   19639.527657      4   970000       1231900    NaN
# 6   Honda   Blue   28401.491610      4   750000        952500    NaN
# 2  Toyota   Blue   20229.334991      3   700000        889000    4.0
# 7   Honda   Blue   34019.888129      4   700000        889000    NaN
# 8  Toyota  White   37290.242387      4   625000        793750    NaN
# 1   Honda    Red   54629.583592      4   500000        635000    4.0
# 5  Toyota  Green   61661.280298      4   450000        571500    7.0
# 0  Toyota  White   93252.330640      4   400000        508000    3.0
# 4  Nissan  White  132439.403356      4   350000        444500    8.0
# 3     BMW  Black    6947.793661      5  2200000       2794000    5.0
#
#    Number of Wheels  Fuel per 100 KM  Fuel Economy  Passed Road Safety
# 9                 4              7.0      2212.000                True
# ...
