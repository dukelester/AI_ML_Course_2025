# %% [markdown]
# # Project 3: Weather Data Analysis
#
# ## Problem Statement:
# A meteorology department wants to study weather patterns, rainfall trends, and seasonal averages.
#
# ### Dataset Suggestion: Daily Weather Dataset (Kaggle)
#
# ### Questions to Solve:
#
#     - Find the hottest and coldest day in the dataset.
#
#     - What is the average monthly temperature?
#
#     - Which year had the highest rainfall?
#
#     - Create a new column for temperature difference (MaxTemp - MinTemp).
#
#     - Are there more rainy days in summer or winter?

# %%
import pandas as pd

# %%
weather_data = pd.read_csv('data/weatherHistory.csv')

weather_data
# Out:
#                       Formatted Date        Summary Precip Type  \
# 0      2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain
# 1      2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain
# 2      2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain
# 3      2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain
# 4      2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain
# ...                              ...            ...         ...
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0             9.472222                  7.388889      0.89            14.1197
# ...

# %%
weather_data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
weather_data.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 96448  2016-09-09 19:00:00.000 +0200  Partly Cloudy        rain
# 96449  2016-09-09 20:00:00.000 +0200  Partly Cloudy        rain
# 96450  2016-09-09 21:00:00.000 +0200  Partly Cloudy        rain
# 96451  2016-09-09 22:00:00.000 +0200  Partly Cloudy        rain
# 96452  2016-09-09 23:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 96448        26.016667                 26.016667      0.43            10.9963
# 96449        24.583333                 24.583333      0.48            10.0947
# 96450        22.038889                 22.038889      0.56             8.9838
# 96451        21.522222                 21.522222      0.60            10.5294
# 96452        20.438889                 20.438889      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
weather_data.describe()
# Out:
#        Temperature (C)  Apparent Temperature (C)      Humidity  \
# count     96453.000000              96453.000000  96453.000000
# mean         11.932678                 10.855029      0.734899
# std           9.551546                 10.696847      0.195473
# min         -21.822222                -27.716667      0.000000
# 25%           4.688889                  2.311111      0.600000
# 50%          12.000000                 12.000000      0.780000
# 75%          18.838889                 18.838889      0.890000
# max          39.905556                 39.344444      1.000000
#
#        Wind Speed (km/h)  Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# count       96453.000000            96453.000000     96453.000000     96453.0
# mean           10.810640              187.509232        10.347325         0.0
# std             6.913571              107.383428         4.192123         0.0
# min             0.000000                0.000000         0.000000         0.0
# ...

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Formatted Date            96453 non-null  object
#  1   Summary                   96453 non-null  object
#  2   Precip Type               95936 non-null  object
#  3   Temperature (C)           96453 non-null  float64
#  4   Apparent Temperature (C)  96453 non-null  float64
#  5   Humidity                  96453 non-null  float64
#  6   Wind Speed (km/h)         96453 non-null  float64
#  7   Wind Bearing (degrees)    96453 non-null  float64
#  8   Visibility (km)           96453 non-null  float64
#  9   Loud Cover                96453 non-null  float64
#  10  Pressure (millibars)      96453 non-null  float64
#  11  Daily Summary             96453 non-null  object
# dtypes: float64(8), object(4)
# memory usage: 8.8+ MB

# %% [markdown]
# 1. Find the hotest and coldest date

# %%
sorted_data = weather_data.sort_values(by="Temperature (C)", ascending=False)
sorted_data.head(2)
# Out:
#                       Formatted Date        Summary Precip Type  \
# 12759  2007-07-22 15:00:00.000 +0200          Clear        rain
# 12737  2007-07-21 17:00:00.000 +0200  Partly Cloudy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 12759        39.905556                 37.538889      0.13            23.5865
# 12737        39.588889                 37.600000      0.15            12.2038
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 12759                   250.0           9.9820         0.0
# 12737                   283.0          10.3523         0.0
#
#        Pressure (millibars)                                      Daily Summary
# 12759               1007.55           Partly cloudy starting in the afternoon.
# 12737               1010.24  Partly cloudy starting in the morning continui...

# %%
sorted_data.tail(2)
# Out:
#                       Formatted Date Summary Precip Type  Temperature (C)  \
# 55490  2012-02-09 02:00:00.000 +0100   Foggy        snow       -21.111111
# 54847  2012-02-10 07:00:00.000 +0100   Foggy        snow       -21.822222
#
#        Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 55490                -21.111111      0.74             3.2200
# 54847                -21.822222      0.80             3.0751
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 55490                   200.0           1.9320         0.0
# 54847                   323.0           1.3685         0.0
#
#        Pressure (millibars)                                      Daily Summary
# 55490               1034.30                               Foggy until morning.
# 54847               1033.66  Foggy starting in the morning continuing until...

# %%
hottest = list(sorted_data.head(1)['Formatted Date'])[0]
coldest = list(sorted_data.tail(1)['Formatted Date'])[0]

# %%
print(f'The hottest date is {hottest} and coldest date is {coldest}')
# Out:
# The hottest date is 2007-07-22 15:00:00.000 +0200 and coldest date is 2012-02-10 07:00:00.000 +0100

# %% [markdown]
# ## 2. What is the average monthly temperature?

# %%
sorted_data.groupby(['Formatted Date'])["Temperature (C)"].mean()
# Out:
# Formatted Date
# 2006-01-01 00:00:00.000 +0100    0.577778
# 2006-01-01 01:00:00.000 +0100    1.161111
# 2006-01-01 02:00:00.000 +0100    1.666667
# 2006-01-01 03:00:00.000 +0100    1.711111
# 2006-01-01 04:00:00.000 +0100    1.183333
#                                    ...
# 2016-12-31 19:00:00.000 +0100    0.488889
# 2016-12-31 20:00:00.000 +0100    0.072222
# 2016-12-31 21:00:00.000 +0100   -0.233333
# 2016-12-31 22:00:00.000 +0100   -0.472222
# 2016-12-31 23:00:00.000 +0100   -0.677778
# Name: Temperature (C), Length: 96429, dtype: float64

# %%
monthly_avg = weather_data.groupby('Formatted Date')["Temperature (C)"].mean()

monthly_avg
# Out:
# Formatted Date
# 2006-01-01 00:00:00.000 +0100    0.577778
# 2006-01-01 01:00:00.000 +0100    1.161111
# 2006-01-01 02:00:00.000 +0100    1.666667
# 2006-01-01 03:00:00.000 +0100    1.711111
# 2006-01-01 04:00:00.000 +0100    1.183333
#                                    ...
# 2016-12-31 19:00:00.000 +0100    0.488889
# 2016-12-31 20:00:00.000 +0100    0.072222
# 2016-12-31 21:00:00.000 +0100   -0.233333
# 2016-12-31 22:00:00.000 +0100   -0.472222
# 2016-12-31 23:00:00.000 +0100   -0.677778
# Name: Temperature (C), Length: 96429, dtype: float64

# %% [markdown]
# #### 4. Which year had the highest rainfall?

# %%
weather_data.head()
# Out:
#                   Formatted Date        Summary Precip Type  Temperature (C)  \
# 0  2006-04-01 00:00:00.000 +0200  Partly Cloudy        rain         9.472222
# 1  2006-04-01 01:00:00.000 +0200  Partly Cloudy        rain         9.355556
# 2  2006-04-01 02:00:00.000 +0200  Mostly Cloudy        rain         9.377778
# 3  2006-04-01 03:00:00.000 +0200  Partly Cloudy        rain         8.288889
# 4  2006-04-01 04:00:00.000 +0200  Mostly Cloudy        rain         8.755556
#
#    Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 0                  7.388889      0.89            14.1197
# 1                  7.227778      0.86            14.2646
# 2                  9.377778      0.89             3.9284
# 3                  5.944444      0.83            14.1036
# 4                  6.977778      0.83            11.0446
#
#    Wind Bearing (degrees)  Visibility (km)  Loud Cover  Pressure (millibars)  \
# 0                   251.0          15.8263         0.0               1015.13
# ...

# %%
sorted_by_humidity = weather_data.sort_values(by="Humidity", ascending=False)
sorted_by_humidity[sorted_by_humidity['Precip Type'] == 'rain']
sorted_by_humidity.head()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 66909  2013-03-25 21:00:00.000 +0100       Overcast        snow
# 33192  2009-11-20 01:00:00.000 +0100          Foggy        rain
# 40083  2010-06-06 03:00:00.000 +0200  Partly Cloudy        rain
# 40084  2010-06-06 04:00:00.000 +0200  Partly Cloudy        rain
# 63727  2013-02-14 07:00:00.000 +0100          Foggy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 66909        -0.094444                 -5.438889       1.0            20.7046
# 33192         5.205556                  3.855556       1.0             6.3917
# 40083        11.577778                 11.577778       1.0             6.1502
# 40084        11.505556                 11.505556       1.0             6.2951
# 63727         2.816667                  0.950000       1.0             6.8103
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
weather_data['Formatted Date'].head(200).astype('datetime64[Y]').dt.to_period('M')
# Out:
# 0      2006-01
# 1      2006-01
# 2      2006-01
# 3      2006-01
# 4      2006-01
#         ...
# 195    2006-01
# 196    2006-01
# 197    2006-01
# 198    2006-01
# 199    2006-01
# Name: Formatted Date, Length: 200, dtype: period[M]

# %%
sorted_by_humidity = weather_data.sort_values(by="Humidity", ascending=False)
sorted_by_humidity = sorted_by_humidity[sorted_by_humidity['Precip Type'] == 'rain']
sorted_by_humidity.head()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 33192  2009-11-20 01:00:00.000 +0100          Foggy        rain
# 40083  2010-06-06 03:00:00.000 +0200  Partly Cloudy        rain
# 40084  2010-06-06 04:00:00.000 +0200  Partly Cloudy        rain
# 63727  2013-02-14 07:00:00.000 +0100          Foggy        rain
# 63726  2013-02-14 06:00:00.000 +0100          Foggy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 33192         5.205556                  3.855556       1.0             6.3917
# 40083        11.577778                 11.577778       1.0             6.1502
# 40084        11.505556                 11.505556       1.0             6.2951
# 63727         2.816667                  0.950000       1.0             6.8103
# 63726         2.711111                  2.711111       1.0             3.3327
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
sorted_by_humidity.tail()
# Out:
#                       Formatted Date        Summary Precip Type  \
# 12615  2007-07-17 15:00:00.000 +0200          Clear        rain
# 12713  2007-07-20 17:00:00.000 +0200  Partly Cloudy        rain
# 12759  2007-07-22 15:00:00.000 +0200          Clear        rain
# 58164  2012-03-26 13:00:00.000 +0200  Partly Cloudy        rain
# 29627  2009-01-25 11:00:00.000 +0100          Foggy        rain
#
#        Temperature (C)  Apparent Temperature (C)  Humidity  Wind Speed (km/h)  \
# 12615        37.777778                 35.388889      0.14            17.4202
# 12713        38.788889                 36.477778      0.14            10.5938
# 12759        39.905556                 37.538889      0.13            23.5865
# 58164        13.888889                 13.888889      0.12            28.9800
# 29627         1.111111                 -3.950000      0.00            20.9300
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# ...

# %%
weather_data.size
# Out:
# 1157436
