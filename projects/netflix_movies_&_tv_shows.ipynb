# %% [markdown]
# # Netflix Movies & TV Shows
#
# 🎬 Dataset: Netflix Titles Dataset
#
# Skills: Data cleaning, grouping, visualization
#
# ## Questions to answer:
#
#     - Count the number of movies vs. TV shows.
#
#     - What’s the most common genre on Netflix?
#
#     - Which country has the most content?
#
#     - Plot a histogram of content release years.
#
#     - Who are the top 5 most frequent directors on Netflix?
#
#     - How many titles were added each year from 2010 to 2021?
#
#     - Find the average duration of movies.
#
#     - Which country has the most TV shows?
#
#     - Word cloud of most common words in movie titles.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load the data 

netflix = pd.read_csv('data/netflix_titles.csv')
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
netflix.tail(10)
# Out:
#      show_id     type               title                 director  \
# 8797   s8798  TV Show           Zak Storm                      NaN
# 8798   s8799    Movie            Zed Plus  Chandra Prakash Dwivedi
# 8799   s8800    Movie               Zenda           Avadhoot Gupte
# 8800   s8801  TV Show  Zindagi Gulzar Hai                      NaN
# 8801   s8802    Movie             Zinzana          Majid Al Ansari
# 8802   s8803    Movie              Zodiac            David Fincher
# 8803   s8804  TV Show         Zombie Dumb                      NaN
# 8804   s8805    Movie          Zombieland          Ruben Fleischer
# 8805   s8806    Movie                Zoom             Peter Hewitt
# 8806   s8807    Movie              Zubaan              Mozez Singh
#
#                                                    cast  \
# 8797  Michael Johnston, Jessica Gee-George, Christin...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8799  Santosh Juvekar, Siddharth Chandekar, Sachit P...
# ...

# %%
netflix.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
columns = netflix.columns
print('Total columns \t', columns, len(columns))

total_rows = len(list(netflix.index))
print('total rows \t', total_rows)
# Out:
# Total columns 	 Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object') 12
# total rows 	 8807

# %%
# Missing data and Null Rate
result = {}
for column in columns:
    null_rate = netflix[column].isna().sum() / len(netflix) * 100
    
    if null_rate > 0:
        result[column] = f'{round(null_rate, 2)} %'
print(f'The Null Rate:  {result}')
# Out:
# The Null Rate:  {'director': '29.91 %', 'cast': '9.37 %', 'country': '9.44 %', 'date_added': '0.11 %', 'rating': '0.05 %', 'duration': '0.03 %'}

# %%
# Handle the missing data
country_mode = netflix['country'].mode()[0]
country_mode

# Replace the null country with modest -> United States

netflix['country'] = netflix['country'].fillna(country_mode)
netflix['cast'].replace(np.nan, 'No Cast', inplace=True)
netflix['director'].replace(np.nan, 'No Director', inplace=True)
netflix['rating'].replace(np.nan, 'PG', inplace=True)

# drop other Nan

netflix.dropna(inplace=True)

# Drop Duplicates

netflix.drop_duplicates(inplace=True)

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
# 4      s5  TV Show           Kota Factory      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
netflix.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8794 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8794 non-null   object
#  1   type          8794 non-null   object
#  2   title         8794 non-null   object
#  3   director      8794 non-null   object
#  4   cast          8794 non-null   object
#  5   country       8794 non-null   object
#  6   date_added    8794 non-null   object
#  7   release_year  8794 non-null   int64
#  8   rating        8794 non-null   object
#  9   duration      8794 non-null   object
#  10  listed_in     8794 non-null   object
#  11  description   8794 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 893.1+ KB

# %%
# Fix the Date

netflix['date_added'] = pd.to_datetime(netflix['date_added'])
netflix['Month'] = netflix['date_added'].dt.month
netflix['Month Name'] = netflix['date_added'].dt.month_name()
netflix['Year'] = netflix['date_added'].dt.year

netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                    No Director
# 2                Julien Leclercq
# 3                    No Director
# 4                    No Director
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
netflix[netflix['Month'] == 9].count()
# Out:
# show_id         769
# type            769
# title           769
# director        769
# cast            769
# country         769
# date_added      769
# release_year    769
# rating          769
# duration        769
# listed_in       769
# description     769
# Month           769
# Year            769
# Month Name      769
# dtype: int64

# %% [markdown]
# 1. Count the number of movies vs. TV shows.

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
# 4      s5  TV Show           Kota Factory      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
movies = netflix[netflix['type'] == 'Movie'].count()
tv_shows = netflix[netflix['type'] == 'TV Show'].count()
tv_shows
# Out:
# show_id         2666
# type            2666
# title           2666
# director        2666
# cast            2666
# country         2666
# date_added      2666
# release_year    2666
# rating          2666
# duration        2666
# listed_in       2666
# description     2666
# Month           2666
# Year            2666
# Month Name      2666
# dtype: int64

# %%
netflix.groupby(by='type').count()
# Out:
#          show_id  title  director  cast  country  date_added  release_year  \
# type
# Movie       6128   6128      6128  6128     6128        6128          6128
# TV Show     2666   2666      2666  2666     2666        2666          2666
#
#          rating  duration  listed_in  description  Month  Year  Month Name
# type
# Movie      6128      6128       6128         6128   6128  6128        6128
# TV Show    2666      2666       2666         2666   2666  2666        2666

# %%
movies = netflix[netflix['type'] == 'Movie']
tv_shows = netflix[netflix['type'] == 'TV Show']
print(f' Total movies is : {len(movies)} and total TV shows is  {len(tv_shows)}')
# Out:
#  Total movies is : 6128 and total TV shows is  2666

# %%
value_counts = netflix['type'].value_counts()
print(value_counts, '\n\n')
print(f' Total movies is : {value_counts[0]} and total TV shows is  {value_counts[1]}')
# Out:
# Movie      6128
# TV Show    2666
# Name: type, dtype: int64
#
#
#  Total movies is : 6128 and total TV shows is  2666

# %%
# Create a bar graph

plt.figure(figsize=(6, 6))
value_counts.plot(kind='bar', color=['orange', 'aqua'])
plt.title('Number of Movies vs TV Shows on Netflix')
plt.xlabel('Type')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
# Pie chart
plt.figure(figsize=(6, 6))
value_counts.plot(kind='pie', autopct='%1.1f%%',colors=['orangered', 'darkgreen'])
plt.title('Total movies and Tv shows Distribution')
plt.ylabel("")
plt.show()

# %% [markdown]
# ## 2. What’s the most common genre on Netflix?
#
# Genres are stored in the listed_in column of Netflix dataset. Each row can have multiple genres separated by commas (e.g. "International TV Shows, Romantic TV Shows, TV Dramas").
#
# To find the most common genre, we’ll split them and count frequencies.

# %%
netflix.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                    No Director
# 2                Julien Leclercq
# 3                    No Director
# 4                    No Director
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
listed_in = netflix['listed_in'].str.split(',').explode().str.strip()
listed_in
# Out:
# 0                  Documentaries
# 1         International TV Shows
# 1                      TV Dramas
# 1                   TV Mysteries
# 2                 Crime TV Shows
#                   ...
# 8805    Children & Family Movies
# 8805                    Comedies
# 8806                      Dramas
# 8806        International Movies
# 8806            Music & Musicals
# Name: listed_in, Length: 19300, dtype: object

# %%
listed_in.value_counts()
# Out:
# International Movies            2752
# Dramas                          2427
# Comedies                        1674
# International TV Shows          1350
# Documentaries                    869
# Action & Adventure               859
# TV Dramas                        762
# Independent Movies               756
# Children & Family Movies         641
# Romantic Movies                  616
# Thrillers                        577
# TV Comedies                      574
# Crime TV Shows                   469
# Kids' TV                         449
# Docuseries                       394
# Music & Musicals                 375
# Romantic TV Shows                370
# Horror Movies                    357
# Stand-Up Comedy                  343
# Reality TV                       255
# British TV Shows                 252
# Sci-Fi & Fantasy                 243
# Sports Movies                    219
# Anime Series                     175
# Spanish-Language TV Shows        173
# ...

# %%
genre_counts = listed_in.value_counts()
print("Top 10 Genres:\n", genre_counts.head(10), '\n\n')
print(f'The most common genre in Netflix is {genre_counts.idxmax()} with {genre_counts.max()}')
print(f'The least common genre in Netflix is {genre_counts.idxmin()} with {genre_counts.min()}')
# Out:
# Top 10 Genres:
#  International Movies        2752
# Dramas                      2427
# Comedies                    1674
# International TV Shows      1350
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    762
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: listed_in, dtype: int64
#
#
# The most common genre in Netflix is International Movies with 2752
# The least common genre in Netflix is TV Shows with 16

# %%
plt.figure(figsize=(15, 6))
genre_counts.head(10).plot(kind='bar', color='purple')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.title('Top 10 Most Common Genres on Netflix')
plt.show()

# %% [markdown]
# 3. Which country has the most content?

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
# 4      s5  TV Show           Kota Factory      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
countries = netflix['country'].value_counts()
countries
# Out:
# United States                             3639
# India                                      972
# United Kingdom                             418
# Japan                                      244
# South Korea                                199
#                                           ...
# Romania, Bulgaria, Hungary                   1
# Uruguay, Guatemala                           1
# France, Senegal, Belgium                     1
# Mexico, United States, Spain, Colombia       1
# United Arab Emirates, Jordan                 1
# Name: country, Length: 748, dtype: int64

# %%
top_ten_countries = countries.head(10)
top_ten_countries

plt.figure(figsize=(16, 8))
plt.title('Top 10 Countries with most content')
top_ten_countries.plot(kind='bar', color='darkgreen')
plt.xlabel('Country')
plt.ylabel('Number of Titles')
plt.show()

# %% [markdown]
# 4. Plot a histogram of content release years

# %%
netflix.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# ...

# %%
netflix.hist(['Year'])
# Out:
# array([[<AxesSubplot:title={'center':'Year'}>]], dtype=object)

# %%
plt.figure(figsize=(16, 8))
netflix.hist('Year', bins=20, color='darkblue')
plt.title('Distribution of Netflix Content by Release Year')
plt.ylabel('Number of Titles')
plt.xlabel('Release Year')
plt.show()

# %% [markdown]
# 5. Who are the top 5 most frequent directors on Netflix?

# %%
netflix.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# ...

# %%
directors = netflix['director']
top_directors = directors.value_counts().head(10)
top_directors

print("Top 5 most frequent directors on Netflix:\n")
print(top_directors.head(6))
# Out:
# Top 5 most frequent directors on Netflix:
#
# No Director               2624
# Rajiv Chilaka               19
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Suhas Kadav                 16
# Jay Karas                   14
# Name: director, dtype: int64

# %%
import pandas as pd

# %%
data = pd.read_csv('data/netflix_titles.csv')
data.head(4)

# Drop rows with missing directors
all_directors = data.dropna(subset=['director'])
all_directors

movie_directors = all_directors[all_directors['type'] == 'Movie']
tv_shows_directors = all_directors[all_directors['type'] == 'TV Show']

top_movie_directors = movie_directors['director'].value_counts()
top_tv_shows_directors = tv_shows_directors['director'].value_counts()


print("🎬 Top 5 Movie Directors:\n", top_movie_directors.head(5))
print("\n📺 Top 5 TV Show Directors:\n", top_tv_shows_directors.head(5))

# Plot side-by-side

fig, axes = plt.subplots(1, 2, figsize=(16, 6))

top_movie_directors.head(10).plot(kind='bar', ax=axes[0], color='orangered')
axes[0].set_title('Top 5 Movie Directors In Netflix')
axes[0].set_xlabel('Director')
axes[0].set_ylabel('Number Of Movies')
axes[0].tick_params(axis='x', rotation=45)

top_tv_shows_directors.head(10).plot(kind='bar', ax=axes[1], color='purple')
axes[1].set_title('Top 5 TV Show Directors In Netflix')
axes[1].set_xlabel('Director')
axes[1].set_ylabel('Number Of TV Shows')
axes[1].tick_params(axis='x', rotation=45)

plt.tight_layout()
plt.show()
# Out:
# 🎬 Top 5 Movie Directors:
#  Rajiv Chilaka             19
# Raúl Campos, Jan Suter    18
# Suhas Kadav               16
# Marcus Raboy              15
# Jay Karas                 14
# Name: director, dtype: int64
#
# 📺 Top 5 TV Show Directors:
#  Alastair Fothergill    3
# Rob Seidenglanz        2
# Hsu Fu-chun            2
# Iginio Straffi         2
# Shin Won-ho            2
# Name: director, dtype: int64

# %% [markdown]
# 6. How many titles were added each year from 2010 to 2021?

# %%
netflix.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
# 4      s5  TV Show           Kota Factory      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
date_range = netflix[netflix['Year'].between(2010, 2021)]
# date_range.sort_values(by='Year', ascending=False).tail(10)
grouped = date_range.groupby('Year').size()
grouped
# Out:
# Year
# 2010       1
# 2011      13
# 2012       3
# 2013      11
# 2014      24
# 2015      82
# 2016     427
# 2017    1187
# 2018    1649
# 2019    2016
# 2020    1879
# 2021    1498
# dtype: int64

# %%
# Plot

plt.figure(figsize=(14, 7))
grouped.plot(kind='bar', color='lightblue')
plt.title('Number of Titles Added to Netflix (2010–2021)')
plt.xlabel('Year')
plt.ylabel('Number of Titles')
plt.show()

print('''

Very few titles before 2014.

Huge spike around 2016–2019 (Netflix expansion).

Slight decline in 2020–2021 (pandemic years, production delays).

''')
# Out:
# Very few titles before 2014.
#
# Huge spike around 2016–2019 (Netflix expansion).
#
# Slight decline in 2020–2021 (pandemic years, production delays).

# %% [markdown]
# 7. Find the average duration of movies.

# %%
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
# 4      s5  TV Show           Kota Factory      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# ...

# %%
movies = netflix[netflix['type'] == 'Movie']
movies.head(10)
# Out:
#    show_id   type                                              title  \
# 0       s1  Movie                               Dick Johnson Is Dead
# 6       s7  Movie                   My Little Pony: A New Generation
# 7       s8  Movie                                            Sankofa
# 9      s10  Movie                                       The Starling
# 12     s13  Movie                                       Je Suis Karl
# 13     s14  Movie                   Confessions of an Invisible Girl
# 16     s17  Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 18     s19  Movie                                          Intrusion
# 22     s23  Movie                                    Avvai Shanmughi
# 23     s24  Movie       Go! Go! Cory Carson: Chrissy Takes the Wheel
#
#                                          director  \
# 0                                 Kirsten Johnson
# 6                   Robert Cullen, José Luis Ucha
# 7                                    Haile Gerima
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6128 entries, 0 to 8806
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       6128 non-null   object
#  1   type          6128 non-null   object
#  2   title         6128 non-null   object
#  3   director      6128 non-null   object
#  4   cast          6128 non-null   object
#  5   country       6128 non-null   object
#  6   date_added    6128 non-null   datetime64[ns]
#  7   release_year  6128 non-null   int64
#  8   rating        6128 non-null   object
#  9   duration      6128 non-null   object
#  10  listed_in     6128 non-null   object
#  11  description   6128 non-null   object
#  12  Month         6128 non-null   int64
#  13  Year          6128 non-null   int64
#  14  Month Name    6128 non-null   object
# dtypes: datetime64[ns](1), int64(3), object(11)
# memory usage: 766.0+ KB

# %%
new_movies = movies['duration'].apply(lambda duration: int(duration.split(' ')[0]))
average = new_movies.mean()

print(f'The average duration for a movie is {round(average, 2)} Minutes')
# Out:
# The average duration for a movie is 99.58 Minutes

# %%
movies = netflix[netflix['type'] == 'Movie']
netflix['Duration Minutes'] = movies['duration'].str.replace('min', '').astype(float)
netflix.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# ...

# %%
movies = netflix[netflix['type'] == 'Movie']
movies.head(4)
movies['Duration Minutes'].mean()
# Out:
# 99.57718668407311

# %%
tv_series = netflix[netflix['type'] == 'TV Show']
tv_series.head(3)

netflix['Series Seasons'] = tv_series['duration'].apply(lambda season: int(season.split(' ')[0]))
# netflix['Series Seasons'] = tv_series['duration'].str.replace('Season', '').astype(int)

# tv_series = netflix[netflix['type'] == 'TV Show']
# tv_series.head(3)
tv_series = netflix[netflix['type'] == 'TV Show']
avg_seasons = tv_series['Series Seasons'].mean()

print(f'The average number of seasons for TV Shows is {round(avg_seasons)}')
# Out:
# The average number of seasons for TV Shows is 2

# %%
# Out:
# 1.7513128282070518

# %% [markdown]
# 8. Which country has the most TV shows?

# %%
netflix.head(4)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water      No Director
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans      No Director
#
#                                                 cast        country  \
# 0                                            No Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...  United States
# 3                                            No Cast  United States
#
#   date_added  release_year rating   duration  \
# 0 2021-09-25          2020  PG-13     90 min
# 1 2021-09-24          2021  TV-MA  2 Seasons
# 2 2021-09-24          2021  TV-MA   1 Season
# 3 2021-09-24          2021  TV-MA   1 Season
#
#                                            listed_in  \
# ...

# %%
countries_count = tv_shows['country'].value_counts().dropna()
top_country = countries_count.idxmax()
top_count = countries_count.max()

print(f"The country with the most TV shows is {top_country} with {top_count} shows.")
# Out:
# The country with the most TV shows is United States with 1144 shows.
